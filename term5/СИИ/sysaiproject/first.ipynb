# %%
import pandas

df = pandas.read_csv("datasets/Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Sex_encoded'] = df['Sex'].map(lambda x: 1 if x == 'male' else 0)
df = df.drop(columns=['Sex'])
df['Sex_encoded']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex_encoded, Length: 891, dtype: int64

# %%
df = df.drop(['Cabin', 'PassengerId', 'Name', 'Ticket'], axis=1)
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare Embarked  Sex_encoded
# 0           0       3  22.0      1      0   7.2500        S            1
# 1           1       1  38.0      1      0  71.2833        C            0
# 2           1       3  26.0      0      0   7.9250        S            0
# 3           1       1  35.0      1      0  53.1000        S            0
# 4           0       3  35.0      0      0   8.0500        S            1
# ..        ...     ...   ...    ...    ...      ...      ...          ...
# 886         0       2  27.0      0      0  13.0000        S            1
# 887         1       1  19.0      0      0  30.0000        S            0
# 888         0       3   NaN      1      2  23.4500        S            0
# 889         1       1  26.0      0      0  30.0000        C            1
# 890         0       3  32.0      0      0   7.7500        Q            1
#
# [891 rows x 8 columns]

# %%
df.nunique()
# Out:
# Survived         2
# Pclass           3
# Age             88
# SibSp            7
# Parch            7
# Fare           248
# Embarked         3
# Sex_encoded      2
# dtype: int64

# %%
df = df.dropna(subset=['Embarked']).copy()
df['Embarked_encoded'] = df['Embarked'].map(lambda x: 1 if x == 'C' else 2 if x == 'S' else 3)
df = df.drop(columns=['Embarked'])
df['Embarked_encoded']
# Out:
# 0      2
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    1
# 890    3
# Name: Embarked_encoded, Length: 889, dtype: int64

# %%
median_age = df['Age'].median()
df['Age'] = df['Age'].fillna(median_age)
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 889, dtype: float64

# %%
df.isna().sum()
# Out:
# Survived            0
# Pclass              0
# Age                 0
# SibSp               0
# Parch               0
# Fare                0
# Sex_encoded         0
# Embarked_encoded    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Titanic correlation matrix')
plt.tight_layout()
plt.show()

# %%
titanic_processed = df.copy()
titanic_processed = titanic_processed.astype({'Survived': 'int64'})
titanic_processed.to_csv('datasets/titanic_preprocessed.csv', index=False)
titanic_processed.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_encoded  \
# 0         0       3  22.0      1      0   7.2500            1
# 1         1       1  38.0      1      0  71.2833            0
# 2         1       3  26.0      0      0   7.9250            0
# 3         1       1  35.0      1      0  53.1000            0
# 4         0       3  35.0      0      0   8.0500            1
#
#    Embarked_encoded
# 0                 2
# 1                 1
# 2                 2
# 3                 2
# 4                 2

# %%
import pandas

df = pandas.read_csv("datasets/California_Houses.csv")
df
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                452600.0         8.3252          41        880           129
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %%
df.describe()
# Out:
#        Median_House_Value  Median_Income    Median_Age     Tot_Rooms  \
# count        20640.000000   20640.000000  20640.000000  20640.000000
# mean        206855.816909       3.870671     28.639486   2635.763081
# std         115395.615874       1.899822     12.585558   2181.615252
# min          14999.000000       0.499900      1.000000      2.000000
# 25%         119600.000000       2.563400     18.000000   1447.750000
# 50%         179700.000000       3.534800     29.000000   2127.000000
# 75%         264725.000000       4.743250     37.000000   3148.000000
# max         500001.000000      15.000100     52.000000  39320.000000
#
#        Tot_Bedrooms    Population    Households      Latitude     Longitude  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean     537.898014   1425.476744    499.539680     35.631861   -119.569704
# std      421.247906   1132.462122    382.329753      2.135952      2.003532
# ...

# %%
df.isna().sum()
# Out:
# Median_House_Value          0
# Median_Income               0
# Median_Age                  0
# Tot_Rooms                   0
# Tot_Bedrooms                0
# Population                  0
# Households                  0
# Latitude                    0
# Longitude                   0
# Distance_to_coast           0
# Distance_to_LA              0
# Distance_to_SanDiego        0
# Distance_to_SanJose         0
# Distance_to_SanFrancisco    0
# dtype: int64

# %%
df = df.dropna().copy()
df.to_csv('datasets/california_preprocessed.csv', index=False)
df.head()
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
df.select_dtypes(include=["object"]).columns
# Out:
# Index([], dtype='object')
